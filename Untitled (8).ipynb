# %% [markdown]
# Chapter 10

# %% [markdown]
# # Programming Exercises 3,5

# %% [raw]
# ## 3. design a class that holds the following personal data: name, address, age, and phone number. write apropriate accessor and mutater methods. also, write a program that creates three instances of the class. one instance, should hold your information, and the other two should hold your friends or family members information

# %%
# define a class to hold personal data
class PersonalData:
    # constructor method to initialize the data
    def __init__(self, name, address, age, phone_number):
        self.name = name
        self.address = address
        self.age = age
        self.phone_number = phone_number

    # accessor methods to get data attributes
    def get_name(self):
        return self.name

    def get_address(self):
        return selfaddress

    def get_age(self):
        return self.age

    def get_phone_number(self):
        return self.phone_number

    # mutator methods to set data attributes
    def set_name(self, name):
        self.name = name

    def set_address(self, address):
        self.address = address

    def set_age(self, age):
        self.age = age

    def set_phone_number(self, phone_number):
        self.phone_number = phone_number

# create instances of the PersonalData class
your_info = PersonalData("Your Name", "Your Address", 25, "Your Phone Number")
friend1_info = PersonalData("Friend 1 Name", "Friend 1 Address", 30, "Friend 1 Phone Number")
friend2_info = PersonalData("Friend 2 Name", "Friend 2 Address", 28, "Friend 2 Phone Number")

# accessing and modifying information for your info
print("Your Information:)
print("Name:", your_info.get_name())
print("Address:", your_info.get_address())
print("Age:", your_info.get_age())
print("Phone Number:", your_info.get_phone_number())

your_info.set_name("Updated Name")
print("Updated Name:", your_info.get_name())

# accessing information for friend 1 info
print("\nFriend 1 Information:")
print("Name:", friend1_info.get_name())
print("Address:", friend1_info.get_address())
print("Age:", friend1_info.get_age())
print("Phone Number:", friend1_info.get_phone_number())

# accessing information for friend 2 info
print("\nFriend 2 Information:")
print("Name:" friend2_info.get_name())
print("Address:", friend2_info.get_address())
print("Age:", friend2_info.get_age())
print("Phone Number:", friend2_info.get_phone_number())
# Out:
#   Input In [16]
#     print("Your Information:)
#                              ^
# SyntaxError: EOL while scanning string literal

# %%
# define a class to hold personal data
class PersonalData:
    # constructor method to initialize the data
    def __init__(self, name, address, age, phone_number):
        self.name = name
        self.address = address
        self.age = age
        self.phone_number = phone_number

    # accessor methods to get data attributes
    def get_name(self):
        return self.name

    def get_address(self):
        return self.address

    def get_age(self):
        return self.age

    def get_phone_number(self):
        return self.phone_number

    # mutator methods to set data attributes
    def set_name(self, name):
        self.name = name

    def set_address(self, address):
        self.address = address

    def set_age(self, age):
        self.age = age

    def set_phone_number(self, phone_number):
        self.phone_number = phone_number

# create instances of the PersonalData class
your_info = PersonalData("Your Name", "Your Address", 25, "Your Phone Number")
friend1_info = PersonalData("Friend 1 Name", "Friend 1 Address", 30, "Friend 1 Phone Number")
friend2_info = PersonalData("Friend 2 Name", "Friend 2 Address", 28, "Friend 2 Phone Number")

# accessing and modifying information for your info
print("Your Information:")
print("Name:", your_info.get_name())
print("Address:", your_info.get_address())
print("Age:", your_info.get_age())
print("Phone Number:", your_info.get_phone_number())

your_info.set_name("Updated Name")
print("Updated Name:", your_info.get_name())

# accessing information for friend 1 info
print("\nFriend 1 Information:")
print("Name:" friend1_info.get_name())
print("Address:", friend1_info.get_address())
print("Age:", friend1_info.get_age())
print("Phone Number:", friend1_info.get_phone_number())

# accessing information for friend 2 info
print("\nFriend 2 Information:")
print("Name:", friend2_info.get_name())
print("Address:", friend2_info.get_address())
print("Age:", friend2_info.get_age())
print("Phone Number:", friend2_info.get_phone_number())
# Out:
#   Input In [39]
#     print("Name:" friend1_info.get_name())
#                   ^
# SyntaxError: invalid syntax

# %%
# define a class to hold personal data
class PersonalData:
    # constructor method to initialize the data
    def __init__(self, name, address, age, phone_number):
        self.name = name
        self.address = address
        self.age = age
        self.phone_number = phone_number

    # accessor methods to get data attributes
    def get_name(self):
        return self.name

    def get_address(self):
        return self.address

    def get_age(self):
        return self.age

    def get_phone_number(self):
        return self.phone_number

    # mutator methods to set data attributes
    def set_name(self, name):
        self.name = name

    def set_address(self, address):
        self.address = address

    def set_age(self, age):
        self.age = age

    def set_phone_number(self, phone_number):
        self.phone_number = phone_number

# create instances of the PersonalData class
your_info = PersonalData("Your Name", "Your Address", 25, "Your Phone Number")
friend1_info = PersonalData("Friend 1 Name", "Friend 1 Address", 30, "Friend 1 Phone Number")
friend2_info = PersonalData("Friend 2 Name", "Friend 2 Address", 28, "Friend 2 Phone Number")

# accessing and modifying information for your info
print("Your Information:")
print("Name:", your_info.get_name())
print("Address:", your_info.get_address())
print("Age:", your_info.get_age())
print("Phone Number:", your_info.get_phone_number())

your_info.set_name("Updated Name")
print("Updated Name:", your_info.get_name())

# accessing information for friend 1 info
print("\nFriend 1 Information:")
print("Name:", friend1_info.get_name())
print("Address:", friend1_info.get_address())
print("Age:", friend1_info.get_age())
print("Phone Number:", friend1_info.get_phone_number())

# accessing information for friend 2 info
print("\nFriend 2 Information:")
print("Name:", friend2_info.get_name())
print("Address:", friend2_info.get_address())
print("Age:", friend2_info.get_age())
print("Phone Number:", friend2_info.get_phone_number())
# Out:
# Your Information:
# Name: Your Name
# Address: Your Address
# Age: 25
# Phone Number: Your Phone Number
# Updated Name: Updated Name
#
# Friend 1 Information:
# Name: Friend 1 Name
# Address: Friend 1 Address
# Age: 30
# Phone Number: Friend 1 Phone Number
#
# Friend 2 Information:
# Name: Friend 2 Name
# Address: Friend 2 Address
# Age: 28
# Phone Number: Friend 2 Phone Number

# %% [markdown]
# ## 5. write a class named RetailItem that holds data about an item in a retail store. the class should store the following data in attributes: item description, units in inventory, and price. once you have written the class, write a program that creates three RetailItem objects and stores the following data in them: item1: description: jacket units: 12 price: 59.95 item2: description: designer jeans units: 40 price:34.95 item3: description: shirt units: 20 price: 24.95

# %%
# define a class named RetailItem to store data about retail items
class RetailItem:
    # constructor method to initialize item data
    def __init__(self, description, units_in_inventory, price):
        self.description = description
        self.units_in_inventory = units_in_inventory
        self.price = price

    # accessor methods to get item attributes
    def get_description(self):
        return self.description

    def get_units_in_inventory(self):
        return self.units_in_inventory

    def get_price(self):
        return self.price

    # mutator methods to set item attributes
    def set_description(self, description):
        self.description = description

    def set_units_in_inventory(self, units_in_inventory):
        self.units_in_inventory = units_in_inventory

    def set_price(self, price):
        self.price = price

# create three RetailItem objects with the specified data
item1 = RetailItem("Jacket", 12, 59.95)
item2 = RetailItem("Designer Jeans", 40, 34.95)
item3 = RetailItem("Shirt", 20, 24.95)

# display the info for each item
print("item1:")
print("description:", item.get_description())
print("units in inventory:", item1.get_units_in_inventory())
print("price:", item1_get_price())
# Out:
# item1:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [50], in <cell line: 36>()
#      34 # display the info for each item
#      35 print("item1:")
# ---> 36 print("description:", item.get_description())
#      37 print("units in inventory:", item1.get_units_in_inventory())
#      38 print("price:", item1_get_price())
#
# NameError: name 'item' is not defined

# %%
# define a class named RetailItem to store data about retail items
class RetailItem:
    # constructor method to initialize item data
    def __init__(self, description, units_in_inventory, price):
        self.description = description
        self.units_in_inventory = units_in_inventory
        self.price = price

    # accessor methods to get item attributes
    def get_description(self):
        return self.description

    def get_units_in_inventory(self):
        return self.units_in_inventory

    def get_price(self):
        return self.price

    # mutator methods to set item attributes
    def set_description(self, description):
        self.description = description

    def set_units_in_inventory(self, units_in_inventory):
        self.units_in_inventory = units_in_inventory

    def set_price(self, price):
        self.price = price

# create three RetailItem objects with the specified data
item1 = RetailItem("Jacket", 12, 59.95)
item2 = RetailItem("Designer Jeans", 40, 34.95)
item3 = RetailItem("Shirt", 20, 24.95)

# display the info for each item
print("item1:")
print("description:", item1.get_description())
print("units in inventory:", item1_get_units_in_inventory())
print("price:", item1.get_price())

print("\nItem 2:")
print("Description:", item2.get_description())
print("Units in Inventory:", item2.get_units_in_inventory())
print("Price:", item2.get_price())

print("\nItem 3:")
print("Description:", item3.get_description())
print("Units in Inventory:", item3.get_units_in_inventory())
print("Price:", item3.get_price())
# Out:
# item1:
# description: Jacket
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [58], in <cell line: 37>()
#      35 print("item1:")
#      36 print("description:", item1.get_description())
# ---> 37 print("units in inventory:", item1_get_units_in_inventory())
#      38 print("price:", item1.get_price())
#      40 print("\nItem 2:")
#
# NameError: name 'item1_get_units_in_inventory' is not defined

# %%
# define a class named RetailItem to store data about retail items
class RetailItem:
    # constructor method to initialize item data
    def __init__(self, description, units_in_inventory, price):
        self.description = description
        self.units_in_inventory = units_in_inventory
        self.price = price

    # accessor methods to get item attributes
    def get_description(self):
        return self.description

    def get_units_in_inventory(self):
        return self.units_in_inventory

    def get_price(self):
        return self.price

    # mutator methods to set item attributes
    def set_description(self, description):
        self.description = description

    def set_units_in_inventory(self, units_in_inventory):
        self.units_in_inventory = units_in_inventory

    def set_price(self, price):
        self.price = price

# create three RetailItem objects with the specified data
item1 = RetailItem("Jacket", 12, 59.95)
item2 = RetailItem("Designer Jeans", 40, 34.95)
item3 = RetailItem("Shirt", 20, 24.95)

# display the info for each item
print("item1:")
print("description:", item1.get_description())
print("units in inventory:", item1.get_units_in_inventory())
print("price:", item1.get_price())

print("\nItem 2:")
print("Description:", item2.get_description())
print("Units in Inventory:", item2.get_units_in_inventory())
print("Price:", item2.get_price())

print("\nItem 3:")
print("Description:", item3.get_description())
print("Units in Inventory:", item3.get_units_in_inventory())
print("Price:", item3.get_price())
# Out:
# item1:
# description: Jacket
# units in inventory: 12
# price: 59.95
#
# Item 2:
# Description: Designer Jeans
# Units in Inventory: 40
# Price: 34.95
#
# Item 3:
# Description: Shirt
# Units in Inventory: 20
# Price: 24.95

# %%
3. flowchart

Start
|
|--- [Class] PersonalData
|      |
|      |--- [Method] __init__(self, name, address, age, phone_number)
|      |      |
|      |      |--- Set attributes: name, address, age, phone_number
|
|      |--- [Method] get_name(self)
|      |      |
|      |      |--- Return self.name
|
|      |--- [Method] get_address(self)
|      |      |
|      |      |--- Return self.address
|
|      |--- [Method] get_age(self)
|      |      |
|      |      |--- Return self.age
|
|      |--- [Method] get_phone_number(self)
|      |      |
|      |      |--- Return self.phone_number
|
|      |--- [Method] set_name(self, name)
|      |      |
|      |      |--- Set self.name to name
|
|      |--- [Method] set_address(self, address)
|      |      |
|      |      |--- Set self.address to address
|
|      |--- [Method] set_age(self, age)
|      |      |
|      |      |--- Set self.age to age
|
|      |--- [Method] set_phone_number(self, phone_number)
|      |      |
|      |      |--- Set self.phone_number to phone_number
|
|--- [Create] your_info
|--- [Create] friend1_info
|--- [Create] friend2_info
|
|--- [Print] Your Information:
|      |--- [Print] Name: Your Name
|      |--- [Print] Address: Your Address
|      |--- [Print] Age: 25
|      |--- [Print] Phone Number: Your Phone Number
|
|      |--- [Method] set_name("Updated Name")
|      |      |
|      |      |--- Set self.name to "Updated Name"
|      |--- [Print] Updated Name: Updated Name
|
|--- [Print] Friend 1 Information:
|      |--- [Print] Name: Friend 1 Name
|      |--- [Print] Address: Friend 1 Address
|      |--- [Print] Age: 30
|      |--- [Print] Phone Number: Friend 1 Phone Number
|
|--- [Print] Friend 2 Information:
       |--- [Print] Name: Friend 2 Name
       |--- [Print] Address: Friend 2 Address
       |--- [Print] Age: 28
       |--- [Print] Phone Number: Friend 2 Phone Number
End
# Out:
#   Input In [71]
#     3. flowchart
#        ^
# SyntaxError: invalid syntax

# %%
5. flowchart
# Out:
# 5.0
